# %% [markdown]
# <a href="https://colab.research.google.com/github/SaadARazzaq/Unemployment-Analysis/blob/main/Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Dataset Link: https://www.kaggle.com/datasets/gokulrajkmv/unemployment-in-india

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/Unemployment in India.csv')

# %%
df.head(10)
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1  Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2  Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3  Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4  Andhra Pradesh   30-09-2019    Monthly                              5.17
# 5  Andhra Pradesh   31-10-2019    Monthly                              3.52
# 6  Andhra Pradesh   30-11-2019    Monthly                              4.12
# 7  Andhra Pradesh   31-12-2019    Monthly                              4.38
# 8  Andhra Pradesh   31-01-2020    Monthly                              4.84
# 9  Andhra Pradesh   29-02-2020    Monthly                              5.91
#
#     Estimated Employed   Estimated Labour Participation Rate (%)   Area
# ...

# %%
df.describe()
# Out:
#         Estimated Unemployment Rate (%)   Estimated Employed  \
# count                        740.000000         7.400000e+02
# mean                          11.787946         7.204460e+06
# std                           10.721298         8.087988e+06
# min                            0.000000         4.942000e+04
# 25%                            4.657500         1.190404e+06
# 50%                            8.350000         4.744178e+06
# 75%                           15.887500         1.127549e+07
# max                           76.740000         4.577751e+07
#
#         Estimated Labour Participation Rate (%)
# count                                740.000000
# mean                                  42.630122
# std                                    8.111094
# min                                   13.330000
# 25%                                   38.062500
# 50%                                   41.160000
# 75%                                   45.505000
# ...

# %%
# !pip install klib

# %%
import klib

# %%
klib.data_cleaning(df)
# Out:
# Long column names detected (>25 characters). Consider renaming the following columns ['estimated_unemployment_rate_percent', 'estimated_labour_participation_rate_percent'].
# Shape of cleaned data: (740, 7) - Remaining NAs: 0
#
#
# Dropped rows: 28
#      of which 0 duplicates. (Rows (first 150 shown): [])
#
# Dropped columns: 0
#      of which 0 single valued.     Columns: []
# Dropped missing values: 196
# Reduced memory by at least: 0.02 MB (-50.0%)
#              region         date frequency  \
# 0    Andhra Pradesh   31-05-2019   Monthly
# 1    Andhra Pradesh   30-06-2019   Monthly
# 2    Andhra Pradesh   31-07-2019   Monthly
# 3    Andhra Pradesh   31-08-2019   Monthly
# 4    Andhra Pradesh   30-09-2019   Monthly
# ..              ...          ...       ...
# 735     West Bengal   29-02-2020   Monthly
# 736     West Bengal   31-03-2020   Monthly
# 737     West Bengal   30-04-2020   Monthly
# 738     West Bengal   31-05-2020   Monthly
# ...

# %%
df.columns
# Out:
# Index(['Region', ' Date', ' Frequency', ' Estimated Unemployment Rate (%)',
#        ' Estimated Employed', ' Estimated Labour Participation Rate (%)',
#        'Area'],
#       dtype='object')

# %%
klib.clean_column_names(df)
# Out:
# Long column names detected (>25 characters). Consider renaming the following columns ['estimated_unemployment_rate_percent', 'estimated_labour_participation_rate_percent'].
#              region         date frequency  \
# 0    Andhra Pradesh   31-05-2019   Monthly
# 1    Andhra Pradesh   30-06-2019   Monthly
# 2    Andhra Pradesh   31-07-2019   Monthly
# 3    Andhra Pradesh   31-08-2019   Monthly
# 4    Andhra Pradesh   30-09-2019   Monthly
# ..              ...          ...       ...
# 763             NaN          NaN       NaN
# 764             NaN          NaN       NaN
# 765             NaN          NaN       NaN
# 766             NaN          NaN       NaN
# 767             NaN          NaN       NaN
#
#      estimated_unemployment_rate_percent  estimated_employed  \
# 0                                   3.65          11999139.0
# 1                                   3.05          11755881.0
# 2                                   3.75          12086707.0
# ...

# %%
klib.data_cleaning(df)
# Out:
# Long column names detected (>25 characters). Consider renaming the following columns ['estimated_unemployment_rate_percent', 'estimated_labour_participation_rate_percent'].
# Shape of cleaned data: (740, 7) - Remaining NAs: 0
#
#
# Dropped rows: 28
#      of which 0 duplicates. (Rows (first 150 shown): [])
#
# Dropped columns: 0
#      of which 0 single valued.     Columns: []
# Dropped missing values: 196
# Reduced memory by at least: 0.02 MB (-50.0%)
#              region         date frequency  \
# 0    Andhra Pradesh   31-05-2019   Monthly
# 1    Andhra Pradesh   30-06-2019   Monthly
# 2    Andhra Pradesh   31-07-2019   Monthly
# 3    Andhra Pradesh   31-08-2019   Monthly
# 4    Andhra Pradesh   30-09-2019   Monthly
# ..              ...          ...       ...
# 735     West Bengal   29-02-2020   Monthly
# 736     West Bengal   31-03-2020   Monthly
# 737     West Bengal   30-04-2020   Monthly
# 738     West Bengal   31-05-2020   Monthly
# ...

# %%
klib.cat_plot(df, figsize=(16,16))
# Out:
# GridSpec(6, 4)

# %%
klib.corr_plot(df, figsize=(16,5))
# Out:
# <Axes: title={'center': 'Feature-correlation (pearson)'}>

# %%
klib.dist_plot(df)
# Out:
# <Axes: xlabel='estimated_labour_participation_rate_percent', ylabel='Density'>
